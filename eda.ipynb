# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
import os
import pandas as pd

# Data files to keep for each sub dir in Data
csv_files = {
    'accident': 'accident.csv',
    'drimpair': 'DrImpair.csv',
    'weather': 'weather.csv'
}

# Create an empty DataFrame to store merged data
merged_data = pd.DataFrame()

for year in range(2016, 2020):
    print(f'Processing year {year}')
    
    file_paths = {key: f'Data/FARS{year}NationalCSV/{filename}' for key, filename in csv_files.items()}
    
    # Check if accident.csv exists first (primary dataset)
    if not os.path.exists(file_paths['accident']):
        print(f"File {file_paths['accident']} does not exist, skipping year {year}.")
        continue
    
    # Read accident dataset
    accident_df = pd.read_csv(file_paths['accident'], encoding='ISO-8859-1')
    
    # Read and merge drimpair data if available
    if os.path.exists(file_paths['drimpair']):
        drimpair_df = pd.read_csv(file_paths['drimpair'], encoding='ISO-8859-1')
        accident_df = accident_df.merge(drimpair_df, on=['STATE', 'ST_CASE'], how='left')
    else:
        print(f"File {file_paths['drimpair']} not found for {year}, skipping.")
    
    # Read and merge weather data if available
    if os.path.exists(file_paths['weather']):
        weather_df = pd.read_csv(file_paths['weather'], encoding='ISO-8859-1')
        accident_df = accident_df.merge(weather_df, on=['STATE', 'ST_CASE'], how='left')
    else:
        print(f"File {file_paths['weather']} not found for {year}, skipping.")
    
    # Append merged data for this year
    merged_data = pd.concat([merged_data, accident_df], ignore_index=True)

# Display merged data structure
merged_data
# Out:
# Processing year 2016
# File Data/FARS2016NationalCSV/weather.csv not found for 2016, skipping.
# Processing year 2017
# /var/folders/rv/_0h726fn3sx8dldgsbxjxv_h0000gn/T/ipykernel_65139/3700357751.py:25: DtypeWarning: Columns (40,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   accident_df = pd.read_csv(file_paths['accident'], encoding='ISO-8859-1')
# File Data/FARS2017NationalCSV/weather.csv not found for 2017, skipping.
# Processing year 2018
# File Data/FARS2018NationalCSV/weather.csv not found for 2018, skipping.
# Processing year 2019
# /var/folders/rv/_0h726fn3sx8dldgsbxjxv_h0000gn/T/ipykernel_65139/3700357751.py:25: DtypeWarning: Columns (40,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   accident_df = pd.read_csv(file_paths['accident'], encoding='ISO-8859-1')
# File Data/FARS2019NationalCSV/weather.csv not found for 2019, skipping.
#         STATE STATENAME_x  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  \
# 0           1     Alabama    10001         1         1         0     0
# 1           1     Alabama    10002         1         1         0     0
# 2           1     Alabama    10003         2         1         1     0
# 3           1     Alabama    10004         1         1         0     0
# 4           1     Alabama    10005         1         1         0     0
# ...       ...         ...      ...       ...       ...       ...   ...
# 210523     56     Wyoming   560119         1         1         0     0
# 210524     56     Wyoming   560120         1         1         0     0
# 210525     56     Wyoming   560120         1         1         0     0
# 210526     56     Wyoming   560121         2         2         0     0
# 210527     56     Wyoming   560121         2         2         0     0
#
#         PERSONS  PERMVIT  PERNOTMVIT  ...  CF2 CF2NAME  CF3 CF3NAME  FATALS  \
# 0             1        1           0  ...    0    None    0    None       1
# 1             2        2           0  ...    0    None    0    None       1
# 2             2        1           1  ...    0    None    0    None       1
# 3             1        1           0  ...    0    None    0    None       1
# 4             1        1           0  ...    0    None    0    None       1
# ...         ...      ...         ...  ...  ...     ...  ...     ...     ...
# 210523        1        1           0  ...    0    None    0    None       1
# 210524        2        2           0  ...    0    None    0    None       1
# 210525        2        2           0  ...    0    None    0    None       1
# 210526        3        3           0  ...    0    None    0    None       2
# 210527        3        3           0  ...    0    None    0    None       2
#
#         DRUNK_DR  STATENAME_y VEH_NO  DRIMPAIR  \
# 0              1      Alabama      1         9
# 1              1      Alabama      1         9
# 2              0      Alabama      1         2
# 3              1      Alabama      1         9
# 4              0      Alabama      1        99
# ...          ...          ...    ...       ...
# 210523         1      Wyoming      1         9
# 210524         1      Wyoming      1         2
# 210525         1      Wyoming      1         9
# 210526         1      Wyoming      1        99
# 210527         1      Wyoming      2        99
#
#                                              DRIMPAIRNAME
# 0       Under the Influence of Alcohol, Drugs or Medic...
# 1       Under the Influence of Alcohol, Drugs or Medic...
# 2                                      Asleep or Fatigued
# 3       Under the Influence of Alcohol, Drugs or Medic...
# 4                                     Unknown if Impaired
# ...                                                   ...
# 210523  Under the Influence of Alcohol, Drugs or Medic...
# 210524                                 Asleep or Fatigued
# 210525  Under the Influence of Alcohol, Drugs or Medic...
# 210526                    Reported as Unknown if Impaired
# 210527                    Reported as Unknown if Impaired
#
# [210528 rows x 95 columns]

# %%
cols_to_drop = ['MONTHNAME', 'DAY_WEEKNAME', 'HOURNAME', 'MINUTENAME', 'STATENAME_y',
                'NHSNAME', 'ROUTENAME', 'RUR_URBNAME', 'FUNC_SYSNAME', 'RD_OWNERNAME', 'LATITUDENAME', 'LONGITUDNAME', 
                'SP_JURNAME', 'HARM_EVNAME', 'MAN_COLLNAME', 'RELJCT1NAME', 'RELJCT2NAME', 'TYP_INTNAME', 'WRK_ZONENAME', 
                'REL_ROADNAME', 'LGT_CONDNAME', 'WEATHER1NAME', 'WEATHER2NAME', 'WEATHERNAME', 'SCH_BUSNAME', 'RAILNAME']
merged_data.drop(columns=[col for col in cols_to_drop if col in merged_data.columns], inplace=True)
merged_data.rename(columns={'STATENAME_x': 'STATENAME'}, inplace=True)

# Perform Exploratory Data Analysis (EDA)
print("Basic Info:")
print(merged_data.info())
print("\nSummary Statistics:")
print(merged_data.describe())
print("\nMissing Values:")
print(merged_data.isnull().sum())
print("\nTop 5 States with Most Accidents:")
print(merged_data['STATENAME'].value_counts().head())
print("\nTop 5 Weather Conditions in Accidents:")
print(merged_data['WEATHER'].value_counts().head())
print("\nTop 5 Harmful Events in Accidents:")
print(merged_data['HARM_EV'].value_counts().head())

# Save cleaned dataset to CSV
output_file = "merged_fars_data.csv"
merged_data.to_csv(output_file, index=False)
print(f"Cleaned data saved to {output_file}")
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210528 entries, 0 to 210527
# Data columns (total 69 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   STATE         210528 non-null  int64
#  1   STATENAME     210528 non-null  object
#  2   ST_CASE       210528 non-null  int64
#  3   VE_TOTAL      210528 non-null  int64
#  4   VE_FORMS      210528 non-null  int64
#  5   PVH_INVL      210528 non-null  int64
#  6   PEDS          210528 non-null  int64
#  7   PERSONS       210528 non-null  int64
#  8   PERMVIT       210528 non-null  int64
#  9   PERNOTMVIT    210528 non-null  int64
#  10  COUNTY        210528 non-null  int64
#  11  COUNTYNAME    210528 non-null  object
#  12  CITY          210528 non-null  int64
#  13  CITYNAME      210528 non-null  object
#  14  DAY           210528 non-null  int64
#  15  DAYNAME       210528 non-null  int64
#  16  MONTH         210528 non-null  int64
#  17  YEAR          210528 non-null  int64
#  18  DAY_WEEK      210528 non-null  int64
#  19  HOUR          210528 non-null  int64
#  20  MINUTE        210528 non-null  int64
#  21  NHS           210528 non-null  int64
#  22  ROUTE         210528 non-null  int64
#  23  TWAY_ID       210528 non-null  object
#  24  TWAY_ID2      63859 non-null   object
#  25  RUR_URB       210528 non-null  int64
#  26  FUNC_SYS      210528 non-null  int64
#  27  RD_OWNER      210528 non-null  int64
#  28  MILEPT        210528 non-null  int64
#  29  MILEPTNAME    210528 non-null  object
#  30  LATITUDE      210528 non-null  float64
#  31  LONGITUD      210528 non-null  float64
#  32  SP_JUR        210528 non-null  int64
#  33  HARM_EV       210528 non-null  int64
#  34  MAN_COLL      210528 non-null  int64
#  35  RELJCT1       210528 non-null  int64
#  36  RELJCT2       210528 non-null  int64
#  37  TYP_INT       210528 non-null  int64
#  38  WRK_ZONE      210528 non-null  int64
#  39  REL_ROAD      210528 non-null  int64
#  40  LGT_COND      210528 non-null  int64
#  41  WEATHER1      210528 non-null  int64
#  42  WEATHER2      210528 non-null  int64
#  43  WEATHER       210528 non-null  int64
#  44  SCH_BUS       210528 non-null  int64
#  45  RAIL          210528 non-null  object
#  46  NOT_HOUR      210528 non-null  int64
#  47  NOT_HOURNAME  210528 non-null  object
#  48  NOT_MIN       210528 non-null  int64
#  49  NOT_MINNAME   210528 non-null  object
#  50  ARR_HOUR      210528 non-null  int64
#  51  ARR_HOURNAME  210528 non-null  object
#  52  ARR_MIN       210528 non-null  int64
#  53  ARR_MINNAME   210528 non-null  object
#  54  HOSP_HR       210528 non-null  int64
#  55  HOSP_HRNAME   210528 non-null  object
#  56  HOSP_MN       210528 non-null  int64
#  57  HOSP_MNNAME   210528 non-null  object
#  58  CF1           210528 non-null  int64
#  59  CF1NAME       210528 non-null  object
#  60  CF2           210528 non-null  int64
#  61  CF2NAME       210528 non-null  object
#  62  CF3           210528 non-null  int64
#  63  CF3NAME       210528 non-null  object
#  64  FATALS        210528 non-null  int64
#  65  DRUNK_DR      210528 non-null  int64
#  66  VEH_NO        210528 non-null  int64
#  67  DRIMPAIR      210528 non-null  int64
#  68  DRIMPAIRNAME  210528 non-null  object
# dtypes: float64(2), int64(50), object(17)
# memory usage: 110.8+ MB
# None
#
# Summary Statistics:
#                STATE        ST_CASE       VE_TOTAL       VE_FORMS  \
# count  210528.000000  210528.000000  210528.000000  210528.000000
# mean       27.043837  271212.755572       1.993265       1.958281
# std        16.389014  163779.570430       1.943859       1.929772
# min         1.000000   10001.000000       1.000000       1.000000
# 25%        12.000000  121850.750000       1.000000       1.000000
# 50%        26.000000  260685.000000       2.000000       2.000000
# 75%        42.000000  420474.000000       2.000000       2.000000
# max        56.000000  560121.000000      64.000000      64.000000
#
#             PVH_INVL           PEDS        PERSONS        PERMVIT  \
# count  210528.000000  210528.000000  210528.000000  210528.000000
# mean        0.034983       0.168538       2.898489       2.889739
# std         0.277632       0.431023       3.398449       3.397241
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       1.000000       1.000000
# 50%         0.000000       0.000000       2.000000       2.000000
# 75%         0.000000       0.000000       3.000000       3.000000
# max        20.000000      23.000000     120.000000     120.000000
#
#           PERNOTMVIT         COUNTY  ...        ARR_MIN        HOSP_HR  \
# count  210528.000000  210528.000000  ...  210528.000000  210528.000000
# mean        0.177288      92.484510  ...      65.004327      70.704951
# std         0.458590      97.130471  ...      36.660559      37.261790
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.000000      31.000000  ...      30.000000      20.000000
# 50%         0.000000      71.000000  ...      98.000000      88.000000
# 75%         0.000000     115.000000  ...      99.000000      99.000000
# max        23.000000     999.000000  ...      99.000000      99.000000
#
#              HOSP_MN            CF1            CF2            CF3  \
# count  210528.000000  210528.000000  210528.000000  210528.000000
# mean       75.345355       2.260478       0.918111       0.738728
# std        31.417030       9.801651       8.660321       8.448627
# min         0.000000       0.000000       0.000000       0.000000
# 25%        50.000000       0.000000       0.000000       0.000000
# 50%        88.000000       0.000000       0.000000       0.000000
# 75%        99.000000       0.000000       0.000000       0.000000
# max        99.000000      99.000000      99.000000      99.000000
#
#               FATALS       DRUNK_DR         VEH_NO       DRIMPAIR
# count  210528.000000  210528.000000  210528.000000  210528.000000
# mean        1.111667       0.262293       1.480962      36.713715
# std         0.410279       0.467044       1.217844      46.605302
# min         1.000000       0.000000       1.000000       0.000000
# 25%         1.000000       0.000000       1.000000       0.000000
# 50%         1.000000       0.000000       1.000000       1.000000
# 75%         1.000000       1.000000       2.000000      98.000000
# max        20.000000       4.000000      64.000000      99.000000
#
# [8 rows x 52 columns]
#
# Missing Values:
# STATE           0
# STATENAME       0
# ST_CASE         0
# VE_TOTAL        0
# VE_FORMS        0
#                ..
# FATALS          0
# DRUNK_DR        0
# VEH_NO          0
# DRIMPAIR        0
# DRIMPAIRNAME    0
# Length: 69, dtype: int64
#
# Top 5 States with Most Accidents:
# California        21420
# Texas             21208
# Florida           18567
# Georgia            8836
# North Carolina     8184
# Name: STATENAME, dtype: int64
#
# Top 5 Weather Conditions in Accidents:
# 1     144886
# 10     30508
# 2      15228
# 98     13076
# 4       2467
# Name: WEATHER, dtype: int64
#
# Top 5 Harmful Events in Accidents:
# 12    119682
# 8      25196
# 1      12287
# 42      9886
# 33      4756
# Name: HARM_EV, dtype: int64
# Cleaned data saved to merged_fars_data.csv

# %%
# # check if STATENAME_x and STATENAME_y are ever different
# if 'STATENAME_x' in merged_data.columns and 'STATENAME_y' in merged_data.columns:
#     different_states = merged_data[merged_data['STATENAME_x'] != merged_data['STATENAME_y']]
#     if not different_states.empty:
#         print("There are rows where STATENAME_x and STATENAME_y are different:")
#         print(different_states[['STATENAME_x', 'STATENAME_y']].head())
#     else:
#         print("STATENAME_x and STATENAME_y are always the same.")
# Out:
# STATENAME_x and STATENAME_y are always the same.
